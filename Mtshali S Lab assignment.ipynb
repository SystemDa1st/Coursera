# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Mtshali Siboniso**

# %% [markdown]
# I am interested in Data Science because I wish to make data driven decisions using the most powerful tools in the current century to make wise or better investment decisions and bring out the best value for my clients by carefully analysing companies data such as sales, revenue, costs and share price as well as overall economy's health to evaluate the company's worth and predict it's future prospects within a reasonable margin of error.

# %% [markdown]
# ### I am trying to find the square of 3

# %%
s = 3**2

print("The square of three(3) is:", s)
# Out:
# The square of three(3) is: 9

# %% [markdown]
# - well, this is going to be interesting.
# - I have no idea what to write here...
# 1. Well how about an interesting (brain f****ng) short story I once read?
# 2. Since you're here, I'm going to assume you want to hear it...
#     *  So, a man was sitting alone at park bench late at night with no recollection of where he is, where he was going or who he was...
#     *  ...confused, he looked up to see a frackled old lady staring at him with a lil smirk on her face. "Where am I? Who am I?" asked the old man.
#     *  The old lady chuckles, "your 3rd & last wish, what is it?" asks the old lady.
#     *  Confused the old man thinks to himself, "my final wish? What about the first and the second?"... reluctant, the old man makes his final wish....
#     - he wishes...............
#
# ***
# _well, it looks like you have to `stay tuned` to the rest of the story...._
#
# ![vectorcarrot190500262.webp](attachment:vectorcarrot190500262.webp)

# %% [markdown]
# _Till we meet again..._
